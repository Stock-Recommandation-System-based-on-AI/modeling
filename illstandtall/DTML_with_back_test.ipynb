# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')

from tensorflow.python.keras.layers import Layer, Dense, LSTM, Dropout, LayerNormalization, Input
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.optimizer_v2 import adam
from keras.callbacks import EarlyStopping
from keras import backend as K
tf.__version__
# Out:
# '2.6.0'

# %%
batch_size = 32
num_stocks = 31
seq_len = 10
num_features = 10
num_market_features = num_features

beta = 0.01
units = 64
ft_dim = 32
n_heads = 12

# %%
def train_vaild_test_split(df):
    codes = df.code.unique()
    train_data = pd.DataFrame()
    vaild_data = pd.DataFrame()
    test_data = pd.DataFrame()
    for c in codes:
        df_stock = df[df.code == c]
        df_stock.reset_index(drop=True, inplace=True)
        times = sorted(df_stock.index.values)
        last_10pct = sorted(df_stock.index.values)[-int(0.01*len(times))] # Last 1% of series
        last_20pct = sorted(df_stock.index.values)[-int(0.02*len(times))] # Last 2% of series
        
        df_train = df_stock[(df_stock.index < last_20pct)]  # Training data are 80% of total data
        df_val = df_stock[(df_stock.index >= last_20pct) & (df_stock.index < last_10pct)]
        df_test = df_stock[(df_stock.index >= last_10pct)]
        stock_test_data_date[df_test.name.unique()[0]] = list(df_test.date)
        train_data = pd.concat([train_data, df_train])
        vaild_data = pd.concat([vaild_data, df_val])
        test_data = pd.concat([test_data, df_test])
    return train_data, vaild_data, test_data

# %%
stock_test_data_date = {} # key = 종목명,  value = [해당 종목 테스트 일자]
kospi31 = pd.read_csv("/content/drive/MyDrive/programmers/project/data/preprocessed_kospi31_daily_stock_chart.csv")
market_index = kospi31[kospi31.code == "U182"]
stocks = kospi31[kospi31.code != "U182"]
market_train_data, market_vaild_data, market_test_data = train_vaild_test_split(market_index)
stock_train_data, stock_vaild_data, stock_test_data = train_vaild_test_split(stocks)
print(market_train_data.shape, market_vaild_data.shape, market_test_data.shape)
print(stock_train_data.shape, stock_vaild_data.shape, stock_test_data.shape)
# Out:
# (4538, 13) (46, 13) (46, 13)
# (140678, 13) (1426, 13) (1426, 13)

# %%
kospi31
# Out:
#            code           name      date  ...     z_d20     z_d25     z_d30
# 0          U182  kospi50_index  20030102  ...  0.000000  0.000000  0.000000
# 1          U182  kospi50_index  20030103  ... -0.021178 -0.021178 -0.021178
# 2          U182  kospi50_index  20030106  ... -0.020145 -0.020145 -0.020145
# 3          U182  kospi50_index  20030107  ...  0.001468  0.001468  0.001468
# 4          U182  kospi50_index  20030108  ...  0.001946  0.001946  0.001946
# ...         ...            ...       ...  ...       ...       ...       ...
# 148155  A005380            현대차  20210909  ...  0.012830  0.022062  0.028937
# 148156  A005380            현대차  20210910  ...  0.019613  0.028765  0.036400
# 148157  A005380            현대차  20210913  ...  0.024146  0.032878  0.041870
# 148158  A005380            현대차  20210914  ...  0.003589  0.010813  0.020175
# 148159  A005380            현대차  20210915  ...  0.000477  0.006587  0.015513
#
# [148160 rows x 13 columns]

# %%
from tensorflow.python.keras.layers import Layer, Dense, LSTM, MultiHeadAttention, LayerNormalization, Dropout, Input
from tensorflow.python.keras.models import Model

class FeatureTransformation(Layer):
    """
    Input: (None, stock, time, feature), (None, 1, time, feature)
    Output: (None, stock, time, ft_dim), (None, 1, time, ft_dim)
    """
    def __init__(self, ft_dim, **kwargs):
        super(FeatureTransformation, self).__init__()
        self.ft_dim = ft_dim

    def build(self, input_shape):
        shape = input_shape[0][1:]
        self.ft_linear = Dense(self.ft_dim,
                               input_shape=shape,
                               kernel_initializer='glorot_uniform',
                               bias_initializer='glorot_uniform',
                               activation='tanh')

    def call(self, inputs, *args, **kwargs):
        stock, market = inputs[0], inputs[1]
        stock = self.ft_linear(stock)
        market = self.ft_linear(market)
        return stock, market

    def get_config(self):
        config = super(FeatureTransformation, self).get_config().copy()
        config.update({'ft_dim':self.ft_dim})
        return config

class AttentionLSTM(Layer):
    """
    Input: (None, time, ft_dim)
    Output: (None, time, units)
    """
    def __init__(self, units, **kwargs):
        super(AttentionLSTM, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.lstm = LSTM(self.units, return_sequences=True, return_state=False)

    def call(self, inputs, *args, **kwargs):
        feature = self.lstm(inputs)
        attn_score = tf.matmul(feature, feature[:, -1:, :], transpose_b=True)
        feature = attn_score * feature
        return feature

    def get_config(self):
        config = super(AttentionLSTM, self).get_config().copy()
        config.update({'units':self.units})
        return config

class ContextNormalize(Layer):
    """
    Input: (None, time, units)
    Output: (None, time, units)
    """
    def __init__(self, **kwargs):
        super(ContextNormalize, self).__init__()

    def build(self, input_shape):
        shape = input_shape[1:]
        self.norm_weight = self.add_weight(name='norm_weight',
                                           shape=shape,
                                           initializer='uniform',
                                           trainable=True)

        self.norm_bias = self.add_weight(name='norm_bias',
                                         shape=shape,
                                         initializer='uniform',
                                         trainable=True)

    def call(self, inputs, *args, **kwargs):
        context = (inputs - tf.math.reduce_mean(inputs))/tf.math.reduce_std(inputs)
        context = self.norm_weight*context + self.norm_bias
        return context

    def get_config(self):
        config = super(ContextNormalize, self).get_config().copy()
        return config

class MultiAttentionLSTM(Layer):
    """
    Input: (None, num_stocks, time, ft_dim)
    Output: (None, time, units) * num_stocks
    """
    def __init__(self, units, num_stocks):
        super(MultiAttentionLSTM, self).__init__()
        self.units = units
        self.num_stocks = num_stocks

    def build(self, input_shape):
        self.attn_lstm = [AttentionLSTM(self.units) for _ in range(self.num_stocks)]
        self.context_norm = [ContextNormalize() for _ in range(self.num_stocks)]

    def call(self, inputs, *args, **kwargs):
        attn_weights = [self.attn_lstm[i](inputs[:, i, :, :]) for i in range(self.num_stocks)]
        attn_weights = [self.context_norm[i](attn_weights[i]) for i in range(self.num_stocks)]
        attn_weights = [tf.expand_dims(x, axis=1) for x in attn_weights]
        attn_weights = tf.concat(attn_weights, axis=1)
        return attn_weights

    def get_config(self):
        config = super(MultiAttentionLSTM, self).get_config().copy()
        config.update({'units': self.units,
                       'num_stocks':self.num_stocks})
        return config


class MultiLevelAggregator(Layer):
    """
    Input: (None, num_stocks, time, units), (None, 1, time, units)
    Output: (None, time, units)
    """
    def __init__(self, beta, **kwargs):
        super(MultiLevelAggregator, self).__init__()
        self.beta = beta

    def call(self, inputs, *args, **kwargs):
        context_stock, context_market = inputs[0], inputs[1]
        context = context_stock + self.beta*context_market
        context = tf.math.reduce_sum(context, axis=2)
        return context

    def get_config(self):
        config = super(MultiLevelAggregator, self).get_config().copy()
        config.update({'beta':self.beta})
        return config

class DataStack(Layer):
    """
    Input: (None, time, units) * num_stocks
    Output: (None, num_stocks, units)
    """
    def __init__(self, **kwargs):
        super(DataStack, self).__init__()

    def call(self, inputs, *args, **kwargs):
        inputs = [tf.expand_dims(x, axis=1) for x in inputs]
        inputs = tf.concat(inputs, axis=1)
        context = tf.math.reduce_sum(inputs, axis=2)
        return context

class NonlinearPrediction(Layer):
    """
    Input: (None, num_stocks, units)
    Output: (None, num_stocks, 1)
    """
    def __init__(self, **kwargs):
        super(NonlinearPrediction, self).__init__()

    def build(self, input_shape):
        hidden_size = input_shape[0][-1]
        self.mlp_linear1 = Dense(4*hidden_size,
                                 input_shape=input_shape,
                                 kernel_initializer='glorot_uniform',
                                 bias_initializer='glorot_uniform',
                                 activation='relu')

        self.mlp_linear2 = Dense(hidden_size,
                                 kernel_initializer='glorot_uniform',
                                 bias_initializer='glorot_uniform',
                                 activation='relu')

        self.mlp_dropout = Dropout(0.15)
        self.mlp_norm = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

        self.pred_linear = Dense(1, activation='sigmoid',
                                 kernel_regularizer='l2', bias_regularizer='l2')

    def call(self, inputs, *args, **kwargs):
        context, attn_weight = inputs[0], inputs[1]
        residual_context = context + attn_weight

        mlp_weight = self.mlp_linear1(residual_context)
        mlp_weight = self.mlp_linear2(mlp_weight)

        residual_context = tf.nn.tanh(residual_context + mlp_weight)
        residual_context = self.mlp_dropout(residual_context)
        residual_context = self.mlp_norm(residual_context)

        output = self.pred_linear(residual_context)
        return output

# %%
from keras import backend as K
def mcc(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    num = tp * tn - fp * fn
    den = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / K.sqrt(den + K.epsilon())

def create_model(n=num_stocks):
    num_stocks = n
    feature_transformation = FeatureTransformation(ft_dim)
    multi_attn_lstm1 = MultiAttentionLSTM(units, num_stocks)
    multi_attn_lstm2 = MultiAttentionLSTM(units, 1)
    multi_lvl_aggregator = MultiLevelAggregator(beta)
    attention = MultiHeadAttention(num_heads=n_heads, key_dim=128, value_dim=128,
                                   dropout=0.15)
    attn_norm = LayerNormalization(epsilon=1e-6)
    nonlinear_pred = NonlinearPrediction()

    stock_inputs = Input(shape=(num_stocks, seq_len, num_features))
    market_inputs = Input(shape=(1, seq_len, num_market_features))

    feature_stock, feature_market = feature_transformation([stock_inputs, market_inputs])
    context_stock = multi_attn_lstm1(feature_stock)
    context_market = multi_attn_lstm2(feature_market)

    context = multi_lvl_aggregator([context_stock, context_market])

    attn_weight = attention(context, context)
    attn_weight = attn_norm(attn_weight)
    output = nonlinear_pred([context, attn_weight])

    model = Model(inputs=[stock_inputs, market_inputs], outputs=output)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', mcc])

    return model

# %%
def get_input_data(df):
    codes = df.code.unique()
    X_data, y_data = [], []
    for c in codes:
        df_stock = df[df.code == c]
        df_stock.drop(columns=['code'], inplace=True)
        df_stock.drop(columns=['name'], inplace=True)
        df_stock.drop(columns=['date'], inplace=True)
        
        nums_features = len(df_stock.columns)
        df_stock = df_stock.values
        
        X, y = [], []
        for i in range(seq_len, len(df_stock)):
            X.append(df_stock[i-seq_len:i])
            y.append(df_stock[:, 3][i])
        X, y = np.array(X), np.array(y)
        X_data.append(X)
        y_data.append(y)
    X_data = np.array(X_data)
    y_data = np.array(y_data)
    X_data = X_data.reshape(-1, len(codes), seq_len, nums_features)
    y_data = y_data.reshape(-1, len(codes))
    print(X_data.shape, y_data.shape)

    return X_data, y_data

# %%
market_train_X, _ = get_input_data(market_train_data)
market_vaild_X, _ = get_input_data(market_vaild_data)
market_test_X, _ = get_input_data(market_test_data)

stock_train_X, stock_train_y = get_input_data(stock_train_data)
stock_vaild_X, stock_vaild_y = get_input_data(stock_vaild_data)
stock_test_X, stock_test_y = get_input_data(stock_test_data)
# Out:
# (4518, 1, 10, 10) (4518, 1)
# (36, 1, 10, 10) (36, 1)
# (36, 1, 10, 10) (36, 1)
# (4518, 31, 10, 10) (4518, 31)
# (36, 31, 10, 10) (36, 31)
# (36, 31, 10, 10) (36, 31)

# %%
def market_stock_split(df):
    market_df = df[df.code=='U182']
    stock_df = df[df.code!='U182']
    return market_df, stock_df

def stock_seperate(stocks):
    stock_names = stocks['name'].unique()
    res = []
    for stock in stock_names:
        res.append(stocks[stocks.name==stock])
    return res

def train_test_split(stocks_df, test_pct=0.2, valid_pct=0.2):
    if not isinstance(stocks_df, (list, tuple)):
        return train_test_split([stocks_df], test_pct, valid_pct)

    stocks_train, stocks_valid, stocks_test = [],[],[]
    for stock in stocks_df:
        test_size = int(len(stock)*test_pct)
        valid_size = int(len(stock)*valid_pct)
        train_size = len(stock) - test_size - valid_size

        stocks_train.append(stock[:train_size])
        stocks_valid.append(stock[train_size:train_size+valid_size])
        stocks_test.append(stock[-test_size:])

    return stocks_train, stocks_valid, stocks_test

def input_target_split(stocks_df):
    target = [stock['close'].apply(lambda x: int(x>0)) for stock in stocks_df]
    return stocks_df, target

def window_split(inputs, targets, window_size=10):
    inputs = inputs.values
    targets = targets.values
    X = []
    y = []
    for i in range(window_size, len(inputs)):
        X.append(inputs[i-window_size:i])
        y.append(targets[i])

    return np.array(X), np.array(y)

def stocks_window_split(stocks_inputs, stocks_target, window_size=10):
    X,y = [],[]
    for j in range(window_size, len(stocks_inputs[0])):
        bucket_X = []
        bucket_y = []
        for i in range(len(stocks_inputs)):
            stock = stocks_inputs[i].values
            target = stocks_target[i].values
            bucket_X.append(stock[j-window_size:j])
            bucket_y.append(target[j])
        X.append(bucket_X)
        y.append(bucket_y)
    return np.array(X), np.array(y)

def prepare_data(path, **kwargs):
    df = pd.read_csv(path)
    market, stocks = market_stock_split(df)
    stocks = stock_seperate(stocks)
    print(len(stocks))
    for i in range(len(stocks)):
        stocks[i].drop(['code','name', 'date'], axis=1, inplace=True)
    market.drop(['code','name', 'date'], axis=1, inplace=True)

    market_train_valid_test = train_test_split(market,
                                               test_pct=kwargs.get('test_pct'),
                                               valid_pct=kwargs.get('valid_pct')) # [m_train], [m_valid], [m_test]
    stock_train_valid_test = train_test_split(stocks,
                                              test_pct=kwargs.get('test_pct'),
                                              valid_pct=kwargs.get('valid_pct')) # [s_train1, ...], [s_valid1, ...], [s_test1, ...]

    print(f'market_train_valid_test: {len(market_train_valid_test)}')
    print(f'market_train_valid_test[0]: {len(market_train_valid_test[0])}')

    print(f'stock_train_valid_test: {len(stock_train_valid_test)}')
    print(f'stock_train_valid_test[0]: {len(stock_train_valid_test[0])}')
    print(f'stock_train_valid_test[0][0]: {stock_train_valid_test[0][0].shape}')

    market_data = [input_target_split(m) for m in market_train_valid_test] # [([m_train_X], [m_train_y]), (...), (...)]
    stock_data = [input_target_split(s) for s in stock_train_valid_test] # [([s_train1_X, ...], [s_train1_y, ...]), (...), (...)]

    print(f'market_data: {len(market_data)}')
    print(f'market_data[0]: {len(market_data[0])}')
    print(f'market_data[0][0]: {len(market_data[0][0])}')
    print(f'market_data[0][0][0]: {market_data[0][0][0].shape}')

    print(f'stock_data: {len(stock_data)}')
    print(f'stock_data[0]: {len(stock_data[0])}')
    print(f'stock_data[0][0]: {len(stock_data[0][0])}')
    print(f'stock_data[0][0][0]: {stock_data[0][0][0].shape}')

    window_size = kwargs['window_size']
    market_data = [stocks_window_split(*m, window_size) for m in market_data]
    stock_data = [stocks_window_split(*s, window_size) for s in stock_data]
    return market_data, stock_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = os.path.abspath('/content/drive/MyDrive/programmers/project/data/preprocessed_kospi31_daily_stock_chart.csv')
option = {
    'window_size':seq_len,
    'test_pct':0.01,
    'valid_pct':0.01
}
market_data, stock_data = prepare_data(path, **option)
(X_train_m, y_train_m), (X_valid_m, y_valid_m), (X_test_m, y_test_m) = market_data
(X_train_s, y_train_s), (X_valid_s, y_valid_s), (X_test_s, y_test_s) = stock_data
# Out:
# 31
# market_train_valid_test: 3
# market_train_valid_test[0]: 1
# stock_train_valid_test: 3
# stock_train_valid_test[0]: 31
# stock_train_valid_test[0][0]: (4538, 10)
# market_data: 3
# market_data[0]: 2
# market_data[0][0]: 1
# market_data[0][0][0]: (4538, 10)
# stock_data: 3
# stock_data[0]: 2
# stock_data[0][0]: 31
# stock_data[0][0][0]: (4538, 10)

# %%
print(X_train_m.shape, y_train_m.shape)
# Out:
# (4528, 1, 10, 10) (4528, 1)

# %%
def get_acc(y_true, y_pred):
    cnt = []
    for t, p in zip(np.ravel(y_true), np.ravel(y_pred)):
        if t == 0 and p == 0:
            cnt.append(1)
        elif t > 0 and p > 0.5:
            cnt.append(1)
        elif t < 0 and p < 0.5:
            cnt.append(1)
        else:
            cnt.append(0)
    cnt = tf.convert_to_tensor(cnt, dtype=tf.float32)
    return tf.reduce_mean(cnt)


def acc(y_true, y_pred):
    score = tf.py_function(func=get_acc, inp=[y_true, y_pred], Tout=tf.float32)
    return score

# %%
# def get_mcc(y_true, y_pred)

def mcc(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    num = tp * tn - fp * fn
    den = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / K.sqrt(den + K.epsilon())

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
model = create_model()
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 31, 10, 10)] 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1, 10, 10)]  0
# __________________________________________________________________________________________________
# feature_transformation (Feature ((None, 31, 10, 32), 352         input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# multi_attention_lstm (MultiAtte (None, 31, 10, 64)   809472      feature_transformation[0][0]
# __________________________________________________________________________________________________
# multi_attention_lstm_1 (MultiAt (None, 1, 10, 64)    26112       feature_transformation[0][1]
# __________________________________________________________________________________________________
# multi_level_aggregator (MultiLe (None, 31, 64)       0           multi_attention_lstm[0][0]
#                                                                  multi_attention_lstm_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, 31, 64)       397888      multi_level_aggregator[0][0]
#                                                                  multi_level_aggregator[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 31, 64)       128         multi_head_attention[0][0]
# __________________________________________________________________________________________________
# nonlinear_prediction (Nonlinear (None, 31, 1)        33281       multi_level_aggregator[0][0]
#                                                                  layer_normalization[0][0]
# ==================================================================================================
# Total params: 1,267,233
# Trainable params: 1,267,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# callback = tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/programmers/project/model/DTML.hdf5',
#                                               monitor='val_loss',
#                                               save_best_only=True, 
#                                               verbose=1)
mc =  tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/programmers/project/model/DTML_final.hdf5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)


history = model.fit([X_train_s, X_train_m], y_train_s,
                    batch_size=batch_size,
                    epochs=100,
                    # callbacks=es,
                    callbacks=[mc, es],
                    validation_data=([X_valid_s, X_valid_m], y_valid_s))
# Out:
# Epoch 1/100
# 142/142 [==============================] - 239s 1s/step - loss: 0.8119 - accuracy: 0.5022 - mcc: -3.0304e-04 - val_loss: 0.7066 - val_accuracy: 0.5475 - val_mcc: 0.0000e+00
#
# Epoch 00001: val_accuracy improved from -inf to 0.54749, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 2/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.7366 - accuracy: 0.5043 - mcc: -0.0023 - val_loss: 0.7036 - val_accuracy: 0.5475 - val_mcc: 0.0000e+00
#
# Epoch 00002: val_accuracy did not improve from 0.54749
# Epoch 3/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.7249 - accuracy: 0.5066 - mcc: 2.4320e-04 - val_loss: 0.7016 - val_accuracy: 0.5475 - val_mcc: 0.0000e+00
#
# Epoch 00003: val_accuracy did not improve from 0.54749
# Epoch 4/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.7155 - accuracy: 0.5093 - mcc: 9.2210e-04 - val_loss: 0.6996 - val_accuracy: 0.5475 - val_mcc: 0.0000e+00
#
# Epoch 00004: val_accuracy did not improve from 0.54749
# Epoch 5/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.7084 - accuracy: 0.5124 - mcc: 0.0068 - val_loss: 0.6979 - val_accuracy: 0.5349 - val_mcc: -0.0328
#
# Epoch 00005: val_accuracy did not improve from 0.54749
# Epoch 6/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.7042 - accuracy: 0.5162 - mcc: 0.0117 - val_loss: 0.6952 - val_accuracy: 0.5466 - val_mcc: 0.0171
#
# Epoch 00006: val_accuracy did not improve from 0.54749
# Epoch 7/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.7008 - accuracy: 0.5165 - mcc: 0.0125 - val_loss: 0.6943 - val_accuracy: 0.5520 - val_mcc: 0.1181
#
# Epoch 00007: val_accuracy improved from 0.54749 to 0.55197, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 8/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6976 - accuracy: 0.5219 - mcc: 0.0138 - val_loss: 0.7071 - val_accuracy: 0.4570 - val_mcc: -0.0277
#
# Epoch 00008: val_accuracy did not improve from 0.55197
# Epoch 9/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6975 - accuracy: 0.5167 - mcc: 0.0169 - val_loss: 0.6958 - val_accuracy: 0.4982 - val_mcc: -0.0304
#
# Epoch 00009: val_accuracy did not improve from 0.55197
# Epoch 10/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6954 - accuracy: 0.5216 - mcc: 0.0206 - val_loss: 0.6908 - val_accuracy: 0.5475 - val_mcc: 0.0999
#
# Epoch 00010: val_accuracy did not improve from 0.55197
# Epoch 11/100
# 142/142 [==============================] - 149s 1s/step - loss: 0.6940 - accuracy: 0.5233 - mcc: 0.0231 - val_loss: 0.6957 - val_accuracy: 0.4830 - val_mcc: -0.0232
#
# Epoch 00011: val_accuracy did not improve from 0.55197
# Epoch 12/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6924 - accuracy: 0.5317 - mcc: 0.0380 - val_loss: 0.6907 - val_accuracy: 0.5493 - val_mcc: 0.0940
#
# Epoch 00012: val_accuracy did not improve from 0.55197
# Epoch 13/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6918 - accuracy: 0.5306 - mcc: 0.0323 - val_loss: 0.6896 - val_accuracy: 0.5493 - val_mcc: 0.1104
#
# Epoch 00013: val_accuracy did not improve from 0.55197
# Epoch 14/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6914 - accuracy: 0.5322 - mcc: 0.0423 - val_loss: 0.6892 - val_accuracy: 0.5493 - val_mcc: 0.0136
#
# Epoch 00014: val_accuracy did not improve from 0.55197
# Epoch 15/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6910 - accuracy: 0.5329 - mcc: 0.0420 - val_loss: 0.6918 - val_accuracy: 0.5466 - val_mcc: 0.0944
#
# Epoch 00015: val_accuracy did not improve from 0.55197
# Epoch 16/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6907 - accuracy: 0.5314 - mcc: 0.0365 - val_loss: 0.6896 - val_accuracy: 0.5520 - val_mcc: 0.1357
#
# Epoch 00016: val_accuracy did not improve from 0.55197
# Epoch 17/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6902 - accuracy: 0.5350 - mcc: 0.0476 - val_loss: 0.6884 - val_accuracy: 0.5493 - val_mcc: 0.1292
#
# Epoch 00017: val_accuracy did not improve from 0.55197
# Epoch 18/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6897 - accuracy: 0.5349 - mcc: 0.0431 - val_loss: 0.6891 - val_accuracy: 0.5538 - val_mcc: 0.1037
#
# Epoch 00018: val_accuracy improved from 0.55197 to 0.55376, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 19/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6897 - accuracy: 0.5362 - mcc: 0.0506 - val_loss: 0.6902 - val_accuracy: 0.5332 - val_mcc: 0.0221
#
# Epoch 00019: val_accuracy did not improve from 0.55376
# Epoch 20/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6895 - accuracy: 0.5363 - mcc: 0.0515 - val_loss: 0.6883 - val_accuracy: 0.5529 - val_mcc: 0.1140
#
# Epoch 00020: val_accuracy did not improve from 0.55376
# Epoch 21/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6890 - accuracy: 0.5375 - mcc: 0.0571 - val_loss: 0.6892 - val_accuracy: 0.5582 - val_mcc: 0.1027
#
# Epoch 00021: val_accuracy improved from 0.55376 to 0.55824, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 22/100
# 142/142 [==============================] - 155s 1s/step - loss: 0.6889 - accuracy: 0.5376 - mcc: 0.0557 - val_loss: 0.6906 - val_accuracy: 0.5439 - val_mcc: 0.0868
#
# Epoch 00022: val_accuracy did not improve from 0.55824
# Epoch 23/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6886 - accuracy: 0.5391 - mcc: 0.0615 - val_loss: 0.6874 - val_accuracy: 0.5511 - val_mcc: 0.0877
#
# Epoch 00023: val_accuracy did not improve from 0.55824
# Epoch 24/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6885 - accuracy: 0.5394 - mcc: 0.0648 - val_loss: 0.6872 - val_accuracy: 0.5502 - val_mcc: 0.1033
#
# Epoch 00024: val_accuracy did not improve from 0.55824
# Epoch 25/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6874 - accuracy: 0.5424 - mcc: 0.0660 - val_loss: 0.6891 - val_accuracy: 0.5448 - val_mcc: 0.0892
#
# Epoch 00025: val_accuracy did not improve from 0.55824
# Epoch 26/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6869 - accuracy: 0.5432 - mcc: 0.0703 - val_loss: 0.6916 - val_accuracy: 0.5341 - val_mcc: 0.1058
#
# Epoch 00026: val_accuracy did not improve from 0.55824
# Epoch 27/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6864 - accuracy: 0.5448 - mcc: 0.0733 - val_loss: 0.6894 - val_accuracy: 0.5448 - val_mcc: 0.0777
#
# Epoch 00027: val_accuracy did not improve from 0.55824
# Epoch 28/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6856 - accuracy: 0.5465 - mcc: 0.0771 - val_loss: 0.6889 - val_accuracy: 0.5439 - val_mcc: 0.1259
#
# Epoch 00028: val_accuracy did not improve from 0.55824
# Epoch 29/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6857 - accuracy: 0.5461 - mcc: 0.0775 - val_loss: 0.6874 - val_accuracy: 0.5600 - val_mcc: 0.1626
#
# Epoch 00029: val_accuracy improved from 0.55824 to 0.56004, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 30/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6851 - accuracy: 0.5505 - mcc: 0.0889 - val_loss: 0.6868 - val_accuracy: 0.5556 - val_mcc: 0.1240
#
# Epoch 00030: val_accuracy did not improve from 0.56004
# Epoch 31/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6842 - accuracy: 0.5531 - mcc: 0.0941 - val_loss: 0.6907 - val_accuracy: 0.5511 - val_mcc: 0.1271
#
# Epoch 00031: val_accuracy did not improve from 0.56004
# Epoch 32/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6837 - accuracy: 0.5521 - mcc: 0.0945 - val_loss: 0.6880 - val_accuracy: 0.5565 - val_mcc: 0.1291
#
# Epoch 00032: val_accuracy did not improve from 0.56004
# Epoch 33/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6826 - accuracy: 0.5529 - mcc: 0.0960 - val_loss: 0.6879 - val_accuracy: 0.5484 - val_mcc: 0.0815
#
# Epoch 00033: val_accuracy did not improve from 0.56004
# Epoch 34/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6807 - accuracy: 0.5584 - mcc: 0.1062 - val_loss: 0.6922 - val_accuracy: 0.5529 - val_mcc: 0.0965
#
# Epoch 00034: val_accuracy did not improve from 0.56004
# Epoch 35/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6805 - accuracy: 0.5593 - mcc: 0.1087 - val_loss: 0.6901 - val_accuracy: 0.5367 - val_mcc: 0.0293
#
# Epoch 00035: val_accuracy did not improve from 0.56004
# Epoch 36/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6798 - accuracy: 0.5610 - mcc: 0.1109 - val_loss: 0.6888 - val_accuracy: 0.5547 - val_mcc: 0.1204
#
# Epoch 00036: val_accuracy did not improve from 0.56004
# Epoch 37/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6786 - accuracy: 0.5621 - mcc: 0.1151 - val_loss: 0.6855 - val_accuracy: 0.5609 - val_mcc: 0.0938
#
# Epoch 00037: val_accuracy improved from 0.56004 to 0.56093, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 38/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6775 - accuracy: 0.5662 - mcc: 0.1245 - val_loss: 0.6899 - val_accuracy: 0.5484 - val_mcc: 0.0032
#
# Epoch 00038: val_accuracy did not improve from 0.56093
# Epoch 39/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6765 - accuracy: 0.5672 - mcc: 0.1260 - val_loss: 0.6905 - val_accuracy: 0.5385 - val_mcc: 0.0676
#
# Epoch 00039: val_accuracy did not improve from 0.56093
# Epoch 40/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6749 - accuracy: 0.5704 - mcc: 0.1353 - val_loss: 0.6918 - val_accuracy: 0.5421 - val_mcc: 0.0720
#
# Epoch 00040: val_accuracy did not improve from 0.56093
# Epoch 41/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6732 - accuracy: 0.5724 - mcc: 0.1357 - val_loss: 0.6927 - val_accuracy: 0.5358 - val_mcc: 0.0177
#
# Epoch 00041: val_accuracy did not improve from 0.56093
# Epoch 42/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6706 - accuracy: 0.5762 - mcc: 0.1417 - val_loss: 0.6924 - val_accuracy: 0.5556 - val_mcc: 0.0954
#
# Epoch 00042: val_accuracy did not improve from 0.56093
# Epoch 43/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6699 - accuracy: 0.5790 - mcc: 0.1516 - val_loss: 0.6961 - val_accuracy: 0.5448 - val_mcc: 0.0213
#
# Epoch 00043: val_accuracy did not improve from 0.56093
# Epoch 44/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6683 - accuracy: 0.5801 - mcc: 0.1511 - val_loss: 0.6965 - val_accuracy: 0.5493 - val_mcc: 0.0375
#
# Epoch 00044: val_accuracy did not improve from 0.56093
# Epoch 45/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6661 - accuracy: 0.5827 - mcc: 0.1580 - val_loss: 0.6907 - val_accuracy: 0.5466 - val_mcc: 0.0881
#
# Epoch 00045: val_accuracy did not improve from 0.56093
# Epoch 46/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6640 - accuracy: 0.5859 - mcc: 0.1631 - val_loss: 0.6982 - val_accuracy: 0.5036 - val_mcc: -0.0656
#
# Epoch 00046: val_accuracy did not improve from 0.56093
# Epoch 47/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6634 - accuracy: 0.5872 - mcc: 0.1673 - val_loss: 0.7002 - val_accuracy: 0.5627 - val_mcc: 0.0590
#
# Epoch 00047: val_accuracy improved from 0.56093 to 0.56272, saving model to /content/drive/MyDrive/programmers/project/model/DTML_final.hdf5
# Epoch 48/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6612 - accuracy: 0.5908 - mcc: 0.1762 - val_loss: 0.7008 - val_accuracy: 0.5573 - val_mcc: 0.0165
#
# Epoch 00048: val_accuracy did not improve from 0.56272
# Epoch 49/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6581 - accuracy: 0.5939 - mcc: 0.1808 - val_loss: 0.6987 - val_accuracy: 0.5466 - val_mcc: 0.0130
#
# Epoch 00049: val_accuracy did not improve from 0.56272
# Epoch 50/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6560 - accuracy: 0.5973 - mcc: 0.1860 - val_loss: 0.7035 - val_accuracy: 0.5170 - val_mcc: 0.0425
#
# Epoch 00050: val_accuracy did not improve from 0.56272
# Epoch 51/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6525 - accuracy: 0.5995 - mcc: 0.1920 - val_loss: 0.7021 - val_accuracy: 0.5376 - val_mcc: 0.0138
#
# Epoch 00051: val_accuracy did not improve from 0.56272
# Epoch 52/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6514 - accuracy: 0.6008 - mcc: 0.1962 - val_loss: 0.7053 - val_accuracy: 0.5430 - val_mcc: 0.0359
#
# Epoch 00052: val_accuracy did not improve from 0.56272
# Epoch 53/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6478 - accuracy: 0.6068 - mcc: 0.2071 - val_loss: 0.7017 - val_accuracy: 0.5385 - val_mcc: 0.0558
#
# Epoch 00053: val_accuracy did not improve from 0.56272
# Epoch 54/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6458 - accuracy: 0.6092 - mcc: 0.2113 - val_loss: 0.6987 - val_accuracy: 0.5188 - val_mcc: 0.0059
#
# Epoch 00054: val_accuracy did not improve from 0.56272
# Epoch 55/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6424 - accuracy: 0.6117 - mcc: 0.2165 - val_loss: 0.7021 - val_accuracy: 0.5323 - val_mcc: -0.0215
#
# Epoch 00055: val_accuracy did not improve from 0.56272
# Epoch 56/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6394 - accuracy: 0.6169 - mcc: 0.2260 - val_loss: 0.7193 - val_accuracy: 0.5358 - val_mcc: 0.0175
#
# Epoch 00056: val_accuracy did not improve from 0.56272
# Epoch 57/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6360 - accuracy: 0.6211 - mcc: 0.2349 - val_loss: 0.7085 - val_accuracy: 0.5394 - val_mcc: -0.0299
#
# Epoch 00057: val_accuracy did not improve from 0.56272
# Epoch 00057: early stopping

# %%
model.save_weights('/content/drive/MyDrive/programmers/project/model/dtml_weights')

# %%
model2 = create_model()
model2.load_weights('/content/drive/MyDrive/programmers/project/model/dtml_weights')
model2.summary()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 31, 10, 10)] 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1, 10, 10)]  0
# __________________________________________________________________________________________________
# feature_transformation_2 (Featu ((None, 31, 10, 32), 352         input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# multi_attention_lstm_4 (MultiAt (None, 31, 10, 64)   809472      feature_transformation_2[0][0]
# __________________________________________________________________________________________________
# multi_attention_lstm_5 (MultiAt (None, 1, 10, 64)    26112       feature_transformation_2[0][1]
# __________________________________________________________________________________________________
# multi_level_aggregator_2 (Multi (None, 31, 64)       0           multi_attention_lstm_4[0][0]
#                                                                  multi_attention_lstm_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_2 (MultiHe (None, 31, 64)       397888      multi_level_aggregator_2[0][0]
#                                                                  multi_level_aggregator_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 31, 64)       128         multi_head_attention_2[0][0]
# __________________________________________________________________________________________________
# nonlinear_prediction_2 (Nonline (None, 31, 1)        33281       multi_level_aggregator_2[0][0]
#                                                                  layer_normalization_2[0][0]
# ==================================================================================================
# Total params: 1,267,233
# Trainable params: 1,267,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_pred2 = model2.predict((X_train_s, X_train_m))
val_pred2 = model2.predict((X_valid_s, X_valid_m))
test_pred2 = model2.predict((X_test_s, X_test_m))

# #Print evaluation metrics for all datasets
train_eval2 = model2.evaluate((X_train_s, X_train_m), y_train_m, verbose=0)
val_eval2 = model2.evaluate((X_valid_s, X_valid_m), y_valid_m, verbose=0)
test_eval2 = model2.evaluate((X_test_s, X_test_m), y_test_m, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(train_eval2[0], train_eval2[1], train_eval2[2]))
print('Validation Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(val_eval2[0], val_eval2[1], val_eval2[2]))
print('Test Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(test_eval2[0], test_eval2[1], test_eval2[2]))
# Out:
#
# Evaluation metrics
# Training Data - Loss: 0.6577, ACC: 0.5940, MCC: 0.2118
# Validation Data - Loss: 0.7447, ACC: 0.4659, MCC: -0.0462
# Test Data - Loss: 0.8033, ACC: 0.4498, MCC: -0.0542

# %%
train_pred = model.predict((X_train_s, X_train_m))
val_pred = model.predict((X_valid_s, X_valid_m))
test_pred = model.predict((X_test_s, X_test_m))

# #Print evaluation metrics for all datasets
train_eval = model.evaluate((X_train_s, X_train_m), y_train_m, verbose=0)
val_eval = model.evaluate((X_valid_s, X_valid_m), y_valid_m, verbose=0)
test_eval = model.evaluate((X_test_s, X_test_m), y_test_m, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))
# Out:
#
# Evaluation metrics
# Training Data - Loss: 0.6577, ACC: 0.5940, MCC: 0.2118
# Validation Data - Loss: 0.7447, ACC: 0.4659, MCC: -0.0462
# Test Data - Loss: 0.8033, ACC: 0.4498, MCC: -0.0542

# %% [markdown]
# ## Back Testing

# %%
import matplotlib.pyplot as plt
import datetime as dt
stock_raw_data = pd.read_csv('/content/drive/MyDrive/programmers/project/data/kospi31-2003-2021.csv')
seed = 10000000 
threshold_prob = 0.57
result1 = dict.fromkeys(list(stock_raw_data['name']))
del result1['kospi50_index'] 
for idx, key in enumerate(result1.keys()):
  result1[key] = idx 
idx_to_name = {}
for k, v in result1.items():
  idx_to_name[v] = k 
first_seed = seed
my_seed = [first_seed]
buy_date_for_x = [dt.datetime.strptime(str(stock_test_data_date['삼성전자'][0]) , "%Y%m%d") - dt.timedelta(days=1)]
for test_day_idx, day_predict in enumerate(test_pred):
  max_idx = -1 
  max_prob = 0
  for stock_idx, predict in enumerate(list(day_predict)):
    if predict[0] > max_prob:
      max_idx = stock_idx 
      max_prob = predict[0] 
    
  # 확률이 50% 이상이면(추후에 더 높게 조정 가능)
  if max_prob > threshold_prob:
    buy_stock_name = idx_to_name[max_idx]
    buy_stock_day  = stock_test_data_date[buy_stock_name][test_day_idx] 
    
    open_ = float(stock_raw_data[(stock_raw_data['name'] == buy_stock_name) & (stock_raw_data['date'] == buy_stock_day)]['open'])
    close = float(stock_raw_data[(stock_raw_data['name'] == buy_stock_name) & (stock_raw_data['date'] == buy_stock_day)]['close'])
    
    
    buy_stock_num = seed // open_
    profit_per_stock = close - open_
    net = round(buy_stock_num * (profit_per_stock) - close*buy_stock_num*0.0023 , 2) 
    
    seed += net 
    seed = round(seed, 2)
    my_seed.append(seed)
    buy_date_for_x.append(dt.datetime.strptime(str(buy_stock_day) , "%Y%m%d")) 
    

print("첫 금액: {}\    {}일치 매수 후 금액: {}\  수익률: {} %  거래 횟수: {}   ----  확률 threshold : {} ".format(first_seed, len(test_pred), seed, round(((seed - first_seed)/seed)*100 , 2), len(my_seed)-1, threshold_prob )) 

fig = plt.figure(figsize = (16,3))
plt.title('My Account') 
plt.ylim(min(my_seed) - 100000, max(my_seed) + 100000)
plt.plot(buy_date_for_x, my_seed, color = 'red') 
plt.show()
# Out:
# 첫 금액: 10000000\    36일치 매수 후 금액: 10554375.0\  수익률: 5.25 %  거래 횟수: 20   ----  확률 threshold : 0.57

# %%
import matplotlib.pyplot as plt
import datetime as dt
stock_raw_data = pd.read_csv('/content/drive/MyDrive/programmers/project/data/kospi31-2003-2021.csv')
seed = 10000000 
threshold_prob = 0.57
result1 = dict.fromkeys(list(stock_raw_data['name']))
del result1['kospi50_index'] 
for idx, key in enumerate(result1.keys()):
  result1[key] = idx 
idx_to_name = {}
for k, v in result1.items():
  idx_to_name[v] = k 
first_seed = seed
my_seed = [first_seed]
buy_date_for_x = [dt.datetime.strptime(str(stock_test_data_date['삼성전자'][0]) , "%Y%m%d") - dt.timedelta(days=1)]
test_pred = model2.predict((X_test_s, X_test_m))
for test_day_idx, day_predict in enumerate(test_pred):
  max_idx_prob = {} # key = idx, value = prob
  for stock_idx, predict in enumerate(list(day_predict)):
    max_idx_prob[stock_idx] = predict[0]
  trade_cnt_for_day = 0
  seed_three_split = seed // 3 
  for max_idx, max_prob in sorted(max_idx_prob.items(), key = lambda x:x[1], reverse = True):
    # 확률이 50% 이상이면(추후에 더 높게 조정 가능)
    if max_prob > threshold_prob:
      trade_cnt_for_day += 1
      buy_stock_name = idx_to_name[max_idx]
      buy_stock_day  = stock_test_data_date[buy_stock_name][test_day_idx] 
      open_ = float(stock_raw_data[(stock_raw_data['name'] == buy_stock_name) & (stock_raw_data['date'] == buy_stock_day)]['open'])
      close = float(stock_raw_data[(stock_raw_data['name'] == buy_stock_name) & (stock_raw_data['date'] == buy_stock_day)]['close'])
      buy_stock_num = seed_three_split // open_ 
      profit_per_stock = close - open_
      net = round(buy_stock_num * (profit_per_stock) - close*buy_stock_num*0.0023 , 2) 
      seed += net 
      seed = round(seed, 2)
    if trade_cnt_for_day == 3 or max_prob < threshold_prob: # 3종목 투자하면 그만두기
      my_seed.append(seed)
      buy_date_for_x.append(dt.datetime.strptime(str(buy_stock_day) , "%Y%m%d")) 
      print(buy_date_for_x)
      break
print("첫 금액: {}\    {}일치 매수 후 금액: {}\  수익률: {} %  거래 횟수: {}   ----  확률 threshold : {} ".format(first_seed, len(test_pred), seed, round(((seed - first_seed)/seed)*100 , 2), len(my_seed)-1, threshold_prob )) 
fig = plt.figure(figsize = (16,3))
plt.title('My Account') 
plt.ylim(min(my_seed) - 100000, max(my_seed) + 100000)
plt.plot(buy_date_for_x, my_seed, color = 'red') 
plt.show()
# Out:
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 24, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 26, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 26, 0, 0), datetime.datetime(2021, 8, 27, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 26, 0, 0), datetime.datetime(2021, 8, 27, 0, 0), datetime.datetime(2021, 8, 30, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 26, 0, 0), datetime.datetime(2021, 8, 27, 0, 0), datetime.datetime(2021, 8, 30, 0, 0), datetime.datetime(2021, 8, 30, 0, 0)]
# [datetime.datetime(2021, 7, 12, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 9, 1, 0, 0), datetime.datetime(2021, 7, 16, 0, 0), datetime.datetime(2021, 7, 19, 0, 0), datetime.datetime(2021, 7, 20, 0, 0), datetime.datetime(2021, 7, 21, 0, 0), datetime.datetime(2021, 7, 22, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 23, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 28, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 7, 30, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 3, 0, 0), datetime.datetime(2021, 8, 5, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 9, 0, 0), datetime.datetime(2021, 8, 19, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 20, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 24, 0, 0), datetime.datetime(2021, 8, 26, 0, 0), datetime.datetime(2021, 8, 27, 0, 0), datetime.datetime(2021, 8, 30, 0, 0), datetime.datetime(2021, 8, 30, 0, 0), datetime.datetime(2021, 9, 1, 0, 0)]
# 첫 금액: 10000000\    36일치 매수 후 금액: 9831929.47\  수익률: -1.71 %  거래 횟수: 36   ----  확률 threshold : 0.57

# %%
stock_raw_data = pd.read_csv('/content/drive/MyDrive/programmers/project/data/kospi31-2003-2021.csv')
seed = 10000000 
threshold_prob = 0.6
result1 = dict.fromkeys(list(stock_raw_data['code']))
del result1['U182'] 
for idx, key in enumerate(result1.keys()):
  result1[key] = idx 
idx_to_name = {}
for k, v in result1.items():
  idx_to_name[v] = k

# %%
from builtins import open
import json
# 임시 , 31개 종목에 대해,매도/매수 여부 key : 종목코드, value: [확률, 매수/매도 여부] ->True 면 매수, False 면 매도
import random 
buy_sell_31 = {} 
for stock_idx, stock_pred in enumerate(test_pred[-1]):
  code = idx_to_name[stock_idx]
  buy_sell_31[code] = [float(stock_pred[0]), bool(stock_pred[0] > 0.52)] 
f =  open('/content/drive/MyDrive/programmers/project/daily_prediction.json', 'w')
json.dump(buy_sell_31, f, ensure_ascii = False, indent ='\t')
