# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')

from tensorflow.python.keras.layers import Layer, Dense, LSTM, Dropout, LayerNormalization, Input
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.optimizer_v2 import adam
from keras.callbacks import EarlyStopping
from keras import backend as K
tf.__version__
# Out:
# '2.6.0'

# %%
batch_size = 32
num_stocks = 31
seq_len = 10
num_features = 10
num_market_features = num_features

beta = 10.01
units = 64
ft_dim = 32
n_heads = 12

# %%
def train_vaild_test_split(df):
    codes = df.code.unique()
    train_data = pd.DataFrame()
    vaild_data = pd.DataFrame()
    test_data = pd.DataFrame()
    for c in codes:
        df_stock = df[df.code == c]
        df_stock.reset_index(drop=True, inplace=True)
        times = sorted(df_stock.index.values)
        last_10pct = sorted(df_stock.index.values)[-int(0.01*len(times))] # Last 1% of series
        last_20pct = sorted(df_stock.index.values)[-int(0.02*len(times))] # Last 2% of series
        
        df_train = df_stock[(df_stock.index < last_20pct)]  # Training data are 80% of total data
        df_val = df_stock[(df_stock.index >= last_20pct) & (df_stock.index < last_10pct)]
        df_test = df_stock[(df_stock.index >= last_10pct)]
        stock_test_data_date[df_test.name.unique()[0]] = list(df_test.date)
        train_data = pd.concat([train_data, df_train])
        vaild_data = pd.concat([vaild_data, df_val])
        test_data = pd.concat([test_data, df_test])
    return train_data, vaild_data, test_data

# %%
stock_test_data_date = {} # key = 종목명,  value = [해당 종목 테스트 일자]
kospi31 = pd.read_csv("preprocessed_kospi31_daily_stock_chart.csv")
market_index = kospi31[kospi31.code == "U182"]
stocks = kospi31[kospi31.code != "U182"]
market_train_data, market_vaild_data, market_test_data = train_vaild_test_split(market_index)
stock_train_data, stock_vaild_data, stock_test_data = train_vaild_test_split(stocks)
print(market_train_data.shape, market_vaild_data.shape, market_test_data.shape)
print(stock_train_data.shape, stock_vaild_data.shape, stock_test_data.shape)
# Out:
# (4528, 13) (46, 13) (46, 13)
# (140368, 13) (1426, 13) (1426, 13)

# %%
from tensorflow.python.keras.layers import Layer, Dense, LSTM, MultiHeadAttention, LayerNormalization, Dropout, Input
from tensorflow.python.keras.models import Model

class FeatureTransformation(Layer):
    """
    Input: (None, stock, time, feature), (None, 1, time, feature)
    Output: (None, stock, time, ft_dim), (None, 1, time, ft_dim)
    """
    def __init__(self, ft_dim, **kwargs):
        super(FeatureTransformation, self).__init__()
        self.ft_dim = ft_dim

    def build(self, input_shape):
        shape = input_shape[0][1:]
        self.ft_linear = Dense(self.ft_dim,
                               input_shape=shape,
                               kernel_initializer='glorot_uniform',
                               bias_initializer='glorot_uniform',
                               activation='tanh')

    def call(self, inputs, *args, **kwargs):
        stock, market = inputs[0], inputs[1]
        stock = self.ft_linear(stock)
        market = self.ft_linear(market)
        return stock, market

    def get_config(self):
        config = super(FeatureTransformation, self).get_config().copy()
        config.update({'ft_dim':self.ft_dim})
        return config

class AttentionLSTM(Layer):
    """
    Input: (None, time, ft_dim)
    Output: (None, time, units)
    """
    def __init__(self, units, **kwargs):
        super(AttentionLSTM, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.lstm = LSTM(self.units, return_sequences=True, return_state=False)

    def call(self, inputs, *args, **kwargs):
        feature = self.lstm(inputs)
        attn_score = tf.matmul(feature, feature[:, -1:, :], transpose_b=True)
        feature = attn_score * feature
        return feature

    def get_config(self):
        config = super(AttentionLSTM, self).get_config().copy()
        config.update({'units':self.units})
        return config

class ContextNormalize(Layer):
    """
    Input: (None, time, units)
    Output: (None, time, units)
    """
    def __init__(self, **kwargs):
        super(ContextNormalize, self).__init__()

    def build(self, input_shape):
        shape = input_shape[1:]
        self.norm_weight = self.add_weight(name='norm_weight',
                                           shape=shape,
                                           initializer='uniform',
                                           trainable=True)

        self.norm_bias = self.add_weight(name='norm_bias',
                                         shape=shape,
                                         initializer='uniform',
                                         trainable=True)

    def call(self, inputs, *args, **kwargs):
        context = (inputs - tf.math.reduce_mean(inputs))/tf.math.reduce_std(inputs)
        context = self.norm_weight*context + self.norm_bias
        return context

    def get_config(self):
        config = super(ContextNormalize, self).get_config().copy()
        return config

class MultiAttentionLSTM(Layer):
    """
    Input: (None, num_stocks, time, ft_dim)
    Output: (None, time, units) * num_stocks
    """
    def __init__(self, units, num_stocks):
        super(MultiAttentionLSTM, self).__init__()
        self.units = units
        self.num_stocks = num_stocks

    def build(self, input_shape):
        self.attn_lstm = [AttentionLSTM(self.units) for _ in range(self.num_stocks)]
        self.context_norm = [ContextNormalize() for _ in range(self.num_stocks)]

    def call(self, inputs, *args, **kwargs):
        attn_weights = [self.attn_lstm[i](inputs[:, i, :, :]) for i in range(self.num_stocks)]
        attn_weights = [self.context_norm[i](attn_weights[i]) for i in range(self.num_stocks)]
        attn_weights = [tf.expand_dims(x, axis=1) for x in attn_weights]
        attn_weights = tf.concat(attn_weights, axis=1)
        return attn_weights

    def get_config(self):
        config = super(MultiAttentionLSTM, self).get_config().copy()
        config.update({'units': self.units,
                       'num_stocks':self.num_stocks})
        return config


class MultiLevelAggregator(Layer):
    """
    Input: (None, num_stocks, time, units), (None, 1, time, units)
    Output: (None, time, units)
    """
    def __init__(self, beta, **kwargs):
        super(MultiLevelAggregator, self).__init__()
        self.beta = beta

    def call(self, inputs, *args, **kwargs):
        context_stock, context_market = inputs[0], inputs[1]
        context = context_stock + self.beta*context_market
        context = tf.math.reduce_sum(context, axis=2)
        return context

    def get_config(self):
        config = super(MultiLevelAggregator, self).get_config().copy()
        config.update({'beta':self.beta})
        return config

class DataStack(Layer):
    """
    Input: (None, time, units) * num_stocks
    Output: (None, num_stocks, units)
    """
    def __init__(self, **kwargs):
        super(DataStack, self).__init__()

    def call(self, inputs, *args, **kwargs):
        inputs = [tf.expand_dims(x, axis=1) for x in inputs]
        inputs = tf.concat(inputs, axis=1)
        context = tf.math.reduce_sum(inputs, axis=2)
        return context

class NonlinearPrediction(Layer):
    """
    Input: (None, num_stocks, units)
    Output: (None, num_stocks, 1)
    """
    def __init__(self, **kwargs):
        super(NonlinearPrediction, self).__init__()

    def build(self, input_shape):
        hidden_size = input_shape[0][-1]
        self.mlp_linear1 = Dense(4*hidden_size,
                                 input_shape=input_shape,
                                 kernel_initializer='glorot_uniform',
                                 bias_initializer='glorot_uniform',
                                 activation='relu')

        self.mlp_linear2 = Dense(hidden_size,
                                 kernel_initializer='glorot_uniform',
                                 bias_initializer='glorot_uniform',
                                 activation='relu')

        self.mlp_dropout = Dropout(0.15)
        self.mlp_norm = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

        self.pred_linear = Dense(1, activation='sigmoid',
                                 kernel_regularizer='l2', bias_regularizer='l2')

    def call(self, inputs, *args, **kwargs):
        context, attn_weight = inputs[0], inputs[1]
        residual_context = context + attn_weight

        mlp_weight = self.mlp_linear1(residual_context)
        mlp_weight = self.mlp_linear2(mlp_weight)

        residual_context = tf.nn.tanh(residual_context + mlp_weight)
        residual_context = self.mlp_dropout(residual_context)
        residual_context = self.mlp_norm(residual_context)

        output = self.pred_linear(residual_context)
        return output

# %%
from keras import backend as K
def mcc(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    num = tp * tn - fp * fn
    den = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / K.sqrt(den + K.epsilon())

def create_model(n=num_stocks):
    num_stocks = n
    feature_transformation = FeatureTransformation(ft_dim)
    multi_attn_lstm1 = MultiAttentionLSTM(units, num_stocks)
    multi_attn_lstm2 = MultiAttentionLSTM(units, 1)
    multi_lvl_aggregator = MultiLevelAggregator(beta)
    attention = MultiHeadAttention(num_heads=n_heads, key_dim=128, value_dim=128,
                                   dropout=0.15)
    attn_norm = LayerNormalization(epsilon=1e-6)
    nonlinear_pred = NonlinearPrediction()

    stock_inputs = Input(shape=(num_stocks, seq_len, num_features))
    market_inputs = Input(shape=(1, seq_len, num_market_features))

    feature_stock, feature_market = feature_transformation([stock_inputs, market_inputs])
    context_stock = multi_attn_lstm1(feature_stock)
    context_market = multi_attn_lstm2(feature_market)

    context = multi_lvl_aggregator([context_stock, context_market])

    attn_weight = attention(context, context)
    attn_weight = attn_norm(attn_weight)
    output = nonlinear_pred([context, attn_weight])

    model = Model(inputs=[stock_inputs, market_inputs], outputs=output)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', mcc])

    return model

# %%
def get_input_data(df):
    codes = df.code.unique()
    X_data, y_data = [], []
    for c in codes:
        df_stock = df[df.code == c]
        df_stock.drop(columns=['code'], inplace=True)
        df_stock.drop(columns=['name'], inplace=True)
        df_stock.drop(columns=['date'], inplace=True)
        
        nums_features = len(df_stock.columns)
        df_stock = df_stock.values
        
        X, y = [], []
        for i in range(seq_len, len(df_stock)):
            X.append(df_stock[i-seq_len:i])
            y.append(df_stock[:, 3][i])
        X, y = np.array(X), np.array(y)
        X_data.append(X)
        y_data.append(y)
    X_data = np.array(X_data)
    y_data = np.array(y_data)
    X_data = X_data.reshape(-1, len(codes), seq_len, nums_features)
    y_data = y_data.reshape(-1, len(codes))
    print(X_data.shape, y_data.shape)

    return X_data, y_data

# %%
market_train_X, _ = get_input_data(market_train_data)
market_vaild_X, _ = get_input_data(market_vaild_data)
market_test_X, _ = get_input_data(market_test_data)

stock_train_X, stock_train_y = get_input_data(stock_train_data)
stock_vaild_X, stock_vaild_y = get_input_data(stock_vaild_data)
stock_test_X, stock_test_y = get_input_data(stock_test_data)
# Out:
# (4518, 1, 10, 10) (4518, 1)
# (36, 1, 10, 10) (36, 1)
# (36, 1, 10, 10) (36, 1)
# (4518, 31, 10, 10) (4518, 31)
# (36, 31, 10, 10) (36, 31)
# (36, 31, 10, 10) (36, 31)

# %%
def market_stock_split(df):
    market_df = df[df.code=='U182']
    stock_df = df[df.code!='U182']
    return market_df, stock_df

def stock_seperate(stocks):
    stock_names = stocks['name'].unique()
    res = []
    for stock in stock_names:
        res.append(stocks[stocks.name==stock])
    return res

def train_test_split(stocks_df, test_pct=0.2, valid_pct=0.2):
    if not isinstance(stocks_df, (list, tuple)):
        return train_test_split([stocks_df], test_pct, valid_pct)

    stocks_train, stocks_valid, stocks_test = [],[],[]
    for stock in stocks_df:
        test_size = int(len(stock)*test_pct)
        valid_size = int(len(stock)*valid_pct)
        train_size = len(stock) - test_size - valid_size

        stocks_train.append(stock[:train_size])
        stocks_valid.append(stock[train_size:train_size+valid_size])
        stocks_test.append(stock[-test_size:])

    return stocks_train, stocks_valid, stocks_test

def input_target_split(stocks_df):
    target = [stock['close'].apply(lambda x: int(x>0)) for stock in stocks_df]
    return stocks_df, target

def window_split(inputs, targets, window_size=10):
    inputs = inputs.values
    targets = targets.values
    X = []
    y = []
    for i in range(window_size, len(inputs)):
        X.append(inputs[i-window_size:i])
        y.append(targets[i])

    return np.array(X), np.array(y)

def stocks_window_split(stocks_inputs, stocks_target, window_size=10):
    X,y = [],[]
    for j in range(window_size, len(stocks_inputs[0])):
        bucket_X = []
        bucket_y = []
        for i in range(len(stocks_inputs)):
            stock = stocks_inputs[i].values
            target = stocks_target[i].values
            bucket_X.append(stock[j-window_size:j])
            bucket_y.append(target[j])
        X.append(bucket_X)
        y.append(bucket_y)
    return np.array(X), np.array(y)

def prepare_data(path, **kwargs):
    df = pd.read_csv(path)
    market, stocks = market_stock_split(df)
    stocks = stock_seperate(stocks)
    print(len(stocks))
    for i in range(len(stocks)):
        stocks[i].drop(['code','name', 'date'], axis=1, inplace=True)
    market.drop(['code','name', 'date'], axis=1, inplace=True)

    market_train_valid_test = train_test_split(market,
                                               test_pct=kwargs.get('test_pct'),
                                               valid_pct=kwargs.get('valid_pct')) # [m_train], [m_valid], [m_test]
    stock_train_valid_test = train_test_split(stocks,
                                              test_pct=kwargs.get('test_pct'),
                                              valid_pct=kwargs.get('valid_pct')) # [s_train1, ...], [s_valid1, ...], [s_test1, ...]

    print(f'market_train_valid_test: {len(market_train_valid_test)}')
    print(f'market_train_valid_test[0]: {len(market_train_valid_test[0])}')

    print(f'stock_train_valid_test: {len(stock_train_valid_test)}')
    print(f'stock_train_valid_test[0]: {len(stock_train_valid_test[0])}')
    print(f'stock_train_valid_test[0][0]: {stock_train_valid_test[0][0].shape}')

    market_data = [input_target_split(m) for m in market_train_valid_test] # [([m_train_X], [m_train_y]), (...), (...)]
    stock_data = [input_target_split(s) for s in stock_train_valid_test] # [([s_train1_X, ...], [s_train1_y, ...]), (...), (...)]

    print(f'market_data: {len(market_data)}')
    print(f'market_data[0]: {len(market_data[0])}')
    print(f'market_data[0][0]: {len(market_data[0][0])}')
    print(f'market_data[0][0][0]: {market_data[0][0][0].shape}')

    print(f'stock_data: {len(stock_data)}')
    print(f'stock_data[0]: {len(stock_data[0])}')
    print(f'stock_data[0][0]: {len(stock_data[0][0])}')
    print(f'stock_data[0][0][0]: {stock_data[0][0][0].shape}')

    window_size = kwargs['window_size']
    market_data = [stocks_window_split(*m, window_size) for m in market_data]
    stock_data = [stocks_window_split(*s, window_size) for s in stock_data]
    return market_data, stock_data

# %%
import os
path = os.path.abspath('preprocessed_kospi31_daily_stock_chart.csv')
option = {
    'window_size':seq_len,
    'test_pct':0.01,
    'valid_pct':0.01
}
market_data, stock_data = prepare_data(path, **option)
(X_train_m, y_train_m), (X_valid_m, y_valid_m), (X_test_m, y_test_m) = market_data
(X_train_s, y_train_s), (X_valid_s, y_valid_s), (X_test_s, y_test_s) = stock_data
# Out:
# 31
# market_train_valid_test: 3
# market_train_valid_test[0]: 1
# stock_train_valid_test: 3
# stock_train_valid_test[0]: 31
# stock_train_valid_test[0][0]: (4528, 10)
# market_data: 3
# market_data[0]: 2
# market_data[0][0]: 1
# market_data[0][0][0]: (4528, 10)
# stock_data: 3
# stock_data[0]: 2
# stock_data[0][0]: 31
# stock_data[0][0][0]: (4528, 10)

# %%
print(X_train_m.shape, y_train_m.shape)
# Out:
# (4518, 1, 10, 10) (4518, 1)

# %%
def get_acc(y_true, y_pred):
    cnt = []
    for t, p in zip(np.ravel(y_true), np.ravel(y_pred)):
        if t == 0 and p == 0:
            cnt.append(1)
        elif t > 0 and p > 0.5:
            cnt.append(1)
        elif t < 0 and p < 0.5:
            cnt.append(1)
        else:
            cnt.append(0)
    cnt = tf.convert_to_tensor(cnt, dtype=tf.float32)
    return tf.reduce_mean(cnt)


def acc(y_true, y_pred):
    score = tf.py_function(func=get_acc, inp=[y_true, y_pred], Tout=tf.float32)
    return score

# %%
# def get_mcc(y_true, y_pred)

def mcc(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    num = tp * tn - fp * fn
    den = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / K.sqrt(den + K.epsilon())

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
model = create_model()
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 31, 10, 10)] 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1, 10, 10)]  0
# __________________________________________________________________________________________________
# feature_transformation_1 (Featu ((None, 31, 10, 32), 352         input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# multi_attention_lstm_2 (MultiAt (None, 31, 10, 64)   809472      feature_transformation_1[0][0]
# __________________________________________________________________________________________________
# multi_attention_lstm_3 (MultiAt (None, 1, 10, 64)    26112       feature_transformation_1[0][1]
# __________________________________________________________________________________________________
# multi_level_aggregator_1 (Multi (None, 31, 64)       0           multi_attention_lstm_2[0][0]
#                                                                  multi_attention_lstm_3[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, 31, 64)       397888      multi_level_aggregator_1[0][0]
#                                                                  multi_level_aggregator_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 31, 64)       128         multi_head_attention_1[0][0]
# __________________________________________________________________________________________________
# nonlinear_prediction_1 (Nonline (None, 31, 1)        33281       multi_level_aggregator_1[0][0]
#                                                                  layer_normalization_1[0][0]
# ==================================================================================================
# Total params: 1,267,233
# Trainable params: 1,267,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# callback = tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/programmers/project/model/DTML.hdf5',
#                                               monitor='val_loss',
#                                               save_best_only=True, 
#                                               verbose=1)
mc =  tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/programmers/project/model/DTML2.hdf5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)


history = model.fit([X_train_s, X_train_m], y_train_s,
                    batch_size=batch_size,
                    epochs=100,
                    # callbacks=es,
                    callbacks=[mc, es],
                    validation_data=([X_valid_s, X_valid_m], y_valid_s))
# Out:
# Epoch 1/100
# 142/142 [==============================] - 239s 1s/step - loss: 0.7594 - accuracy: 0.5049 - mcc: -0.0011 - val_loss: 0.7107 - val_accuracy: 0.5233 - val_mcc: 0.0000e+00
#
# Epoch 00001: val_accuracy improved from -inf to 0.52330, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 2/100
# 142/142 [==============================] - 155s 1s/step - loss: 0.7324 - accuracy: 0.5066 - mcc: 0.0015 - val_loss: 0.7056 - val_accuracy: 0.5233 - val_mcc: 0.0000e+00
#
# Epoch 00002: val_accuracy did not improve from 0.52330
# Epoch 3/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.7201 - accuracy: 0.5090 - mcc: 0.0051 - val_loss: 0.7038 - val_accuracy: 0.5233 - val_mcc: 0.0000e+00
#
# Epoch 00003: val_accuracy did not improve from 0.52330
# Epoch 4/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.7114 - accuracy: 0.5105 - mcc: 0.0061 - val_loss: 0.6991 - val_accuracy: 0.5233 - val_mcc: 0.0000e+00
#
# Epoch 00004: val_accuracy did not improve from 0.52330
# Epoch 5/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.7050 - accuracy: 0.5098 - mcc: 0.0017 - val_loss: 0.6969 - val_accuracy: 0.5251 - val_mcc: 0.0405
#
# Epoch 00005: val_accuracy improved from 0.52330 to 0.52509, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 6/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.7008 - accuracy: 0.5124 - mcc: 0.0031 - val_loss: 0.6963 - val_accuracy: 0.5233 - val_mcc: 0.0000e+00
#
# Epoch 00006: val_accuracy did not improve from 0.52509
# Epoch 7/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6979 - accuracy: 0.5156 - mcc: 0.0084 - val_loss: 0.6945 - val_accuracy: 0.5269 - val_mcc: 0.0283
#
# Epoch 00007: val_accuracy improved from 0.52509 to 0.52688, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 8/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6959 - accuracy: 0.5162 - mcc: 0.0085 - val_loss: 0.6968 - val_accuracy: 0.5233 - val_mcc: 0.0000e+00
#
# Epoch 00008: val_accuracy did not improve from 0.52688
# Epoch 9/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6940 - accuracy: 0.5221 - mcc: 0.0135 - val_loss: 0.6937 - val_accuracy: 0.5179 - val_mcc: 0.0342
#
# Epoch 00009: val_accuracy did not improve from 0.52688
# Epoch 10/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6936 - accuracy: 0.5222 - mcc: 0.0167 - val_loss: 0.6933 - val_accuracy: 0.5188 - val_mcc: 0.0423
#
# Epoch 00010: val_accuracy did not improve from 0.52688
# Epoch 11/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6928 - accuracy: 0.5230 - mcc: 0.0167 - val_loss: 0.6929 - val_accuracy: 0.5251 - val_mcc: 0.0178
#
# Epoch 00011: val_accuracy did not improve from 0.52688
# Epoch 12/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6918 - accuracy: 0.5268 - mcc: 0.0230 - val_loss: 0.6946 - val_accuracy: 0.5260 - val_mcc: 0.0206
#
# Epoch 00012: val_accuracy did not improve from 0.52688
# Epoch 13/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6917 - accuracy: 0.5278 - mcc: 0.0199 - val_loss: 0.6928 - val_accuracy: 0.5224 - val_mcc: 7.9908e-04
#
# Epoch 00013: val_accuracy did not improve from 0.52688
# Epoch 14/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6915 - accuracy: 0.5279 - mcc: 0.0226 - val_loss: 0.6930 - val_accuracy: 0.5305 - val_mcc: 0.0857
#
# Epoch 00014: val_accuracy improved from 0.52688 to 0.53047, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 15/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6914 - accuracy: 0.5281 - mcc: 0.0261 - val_loss: 0.6923 - val_accuracy: 0.5332 - val_mcc: 0.1103
#
# Epoch 00015: val_accuracy improved from 0.53047 to 0.53315, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 16/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6916 - accuracy: 0.5281 - mcc: 0.0245 - val_loss: 0.6921 - val_accuracy: 0.5278 - val_mcc: 0.0986
#
# Epoch 00016: val_accuracy did not improve from 0.53315
# Epoch 17/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6914 - accuracy: 0.5272 - mcc: 0.0281 - val_loss: 0.6953 - val_accuracy: 0.5242 - val_mcc: 0.0092
#
# Epoch 00017: val_accuracy did not improve from 0.53315
# Epoch 18/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6913 - accuracy: 0.5284 - mcc: 0.0326 - val_loss: 0.6966 - val_accuracy: 0.5242 - val_mcc: -0.0334
#
# Epoch 00018: val_accuracy did not improve from 0.53315
# Epoch 19/100
# 142/142 [==============================] - 155s 1s/step - loss: 0.6910 - accuracy: 0.5302 - mcc: 0.0356 - val_loss: 0.6922 - val_accuracy: 0.5278 - val_mcc: 0.0963
#
# Epoch 00019: val_accuracy did not improve from 0.53315
# Epoch 20/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6911 - accuracy: 0.5293 - mcc: 0.0402 - val_loss: 0.6917 - val_accuracy: 0.5305 - val_mcc: 0.0569
#
# Epoch 00020: val_accuracy did not improve from 0.53315
# Epoch 21/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6908 - accuracy: 0.5326 - mcc: 0.0422 - val_loss: 0.6924 - val_accuracy: 0.5206 - val_mcc: -0.0093
#
# Epoch 00021: val_accuracy did not improve from 0.53315
# Epoch 22/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6905 - accuracy: 0.5316 - mcc: 0.0410 - val_loss: 0.6900 - val_accuracy: 0.5412 - val_mcc: 0.1381
#
# Epoch 00022: val_accuracy improved from 0.53315 to 0.54122, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 23/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6906 - accuracy: 0.5290 - mcc: 0.0359 - val_loss: 0.6911 - val_accuracy: 0.5367 - val_mcc: 0.0853
#
# Epoch 00023: val_accuracy did not improve from 0.54122
# Epoch 24/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6899 - accuracy: 0.5340 - mcc: 0.0432 - val_loss: 0.6931 - val_accuracy: 0.5287 - val_mcc: 0.0346
#
# Epoch 00024: val_accuracy did not improve from 0.54122
# Epoch 25/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6897 - accuracy: 0.5345 - mcc: 0.0460 - val_loss: 0.6899 - val_accuracy: 0.5538 - val_mcc: 0.1378
#
# Epoch 00025: val_accuracy improved from 0.54122 to 0.55376, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 26/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6894 - accuracy: 0.5372 - mcc: 0.0522 - val_loss: 0.6887 - val_accuracy: 0.5412 - val_mcc: 0.0977
#
# Epoch 00026: val_accuracy did not improve from 0.55376
# Epoch 27/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6900 - accuracy: 0.5346 - mcc: 0.0520 - val_loss: 0.6906 - val_accuracy: 0.5367 - val_mcc: 0.1047
#
# Epoch 00027: val_accuracy did not improve from 0.55376
# Epoch 28/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6889 - accuracy: 0.5380 - mcc: 0.0534 - val_loss: 0.6905 - val_accuracy: 0.5305 - val_mcc: 0.0716
#
# Epoch 00028: val_accuracy did not improve from 0.55376
# Epoch 29/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6891 - accuracy: 0.5391 - mcc: 0.0584 - val_loss: 0.6908 - val_accuracy: 0.5296 - val_mcc: 0.0655
#
# Epoch 00029: val_accuracy did not improve from 0.55376
# Epoch 30/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6889 - accuracy: 0.5378 - mcc: 0.0549 - val_loss: 0.6888 - val_accuracy: 0.5511 - val_mcc: 0.1421
#
# Epoch 00030: val_accuracy did not improve from 0.55376
# Epoch 31/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6886 - accuracy: 0.5413 - mcc: 0.0669 - val_loss: 0.6878 - val_accuracy: 0.5511 - val_mcc: 0.1108
#
# Epoch 00031: val_accuracy did not improve from 0.55376
# Epoch 32/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6884 - accuracy: 0.5393 - mcc: 0.0598 - val_loss: 0.6886 - val_accuracy: 0.5538 - val_mcc: 0.1695
#
# Epoch 00032: val_accuracy did not improve from 0.55376
# Epoch 33/100
# 142/142 [==============================] - 155s 1s/step - loss: 0.6883 - accuracy: 0.5415 - mcc: 0.0646 - val_loss: 0.6974 - val_accuracy: 0.5242 - val_mcc: 0.0193
#
# Epoch 00033: val_accuracy did not improve from 0.55376
# Epoch 34/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6886 - accuracy: 0.5394 - mcc: 0.0609 - val_loss: 0.6900 - val_accuracy: 0.5466 - val_mcc: 0.0901
#
# Epoch 00034: val_accuracy did not improve from 0.55376
# Epoch 35/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6881 - accuracy: 0.5399 - mcc: 0.0605 - val_loss: 0.6902 - val_accuracy: 0.5358 - val_mcc: 0.0966
#
# Epoch 00035: val_accuracy did not improve from 0.55376
# Epoch 36/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6881 - accuracy: 0.5403 - mcc: 0.0645 - val_loss: 0.6880 - val_accuracy: 0.5529 - val_mcc: 0.1311
#
# Epoch 00036: val_accuracy did not improve from 0.55376
# Epoch 37/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6888 - accuracy: 0.5388 - mcc: 0.0662 - val_loss: 0.6891 - val_accuracy: 0.5314 - val_mcc: 0.0831
#
# Epoch 00037: val_accuracy did not improve from 0.55376
# Epoch 38/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6874 - accuracy: 0.5437 - mcc: 0.0738 - val_loss: 0.6882 - val_accuracy: 0.5457 - val_mcc: 0.1072
#
# Epoch 00038: val_accuracy did not improve from 0.55376
# Epoch 39/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6880 - accuracy: 0.5423 - mcc: 0.0683 - val_loss: 0.6899 - val_accuracy: 0.5475 - val_mcc: 0.1257
#
# Epoch 00039: val_accuracy did not improve from 0.55376
# Epoch 40/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6875 - accuracy: 0.5445 - mcc: 0.0704 - val_loss: 0.6892 - val_accuracy: 0.5323 - val_mcc: 0.0951
#
# Epoch 00040: val_accuracy did not improve from 0.55376
# Epoch 41/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6871 - accuracy: 0.5445 - mcc: 0.0749 - val_loss: 0.6883 - val_accuracy: 0.5573 - val_mcc: 0.1963
#
# Epoch 00041: val_accuracy improved from 0.55376 to 0.55735, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 42/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6870 - accuracy: 0.5444 - mcc: 0.0721 - val_loss: 0.6887 - val_accuracy: 0.5439 - val_mcc: 0.0600
#
# Epoch 00042: val_accuracy did not improve from 0.55735
# Epoch 43/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6871 - accuracy: 0.5436 - mcc: 0.0714 - val_loss: 0.6872 - val_accuracy: 0.5484 - val_mcc: 0.0923
#
# Epoch 00043: val_accuracy did not improve from 0.55735
# Epoch 44/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6862 - accuracy: 0.5475 - mcc: 0.0783 - val_loss: 0.6880 - val_accuracy: 0.5332 - val_mcc: 0.0332
#
# Epoch 00044: val_accuracy did not improve from 0.55735
# Epoch 45/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6871 - accuracy: 0.5445 - mcc: 0.0735 - val_loss: 0.6884 - val_accuracy: 0.5421 - val_mcc: 0.0879
#
# Epoch 00045: val_accuracy did not improve from 0.55735
# Epoch 46/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6862 - accuracy: 0.5488 - mcc: 0.0839 - val_loss: 0.6852 - val_accuracy: 0.5609 - val_mcc: 0.1383
#
# Epoch 00046: val_accuracy improved from 0.55735 to 0.56093, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 47/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6869 - accuracy: 0.5461 - mcc: 0.0808 - val_loss: 0.6899 - val_accuracy: 0.5403 - val_mcc: 0.1115
#
# Epoch 00047: val_accuracy did not improve from 0.56093
# Epoch 48/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6861 - accuracy: 0.5494 - mcc: 0.0860 - val_loss: 0.6886 - val_accuracy: 0.5511 - val_mcc: 0.1204
#
# Epoch 00048: val_accuracy did not improve from 0.56093
# Epoch 49/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6868 - accuracy: 0.5456 - mcc: 0.0759 - val_loss: 0.6921 - val_accuracy: 0.5341 - val_mcc: 0.0551
#
# Epoch 00049: val_accuracy did not improve from 0.56093
# Epoch 50/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6857 - accuracy: 0.5502 - mcc: 0.0839 - val_loss: 0.6920 - val_accuracy: 0.5332 - val_mcc: 0.0864
#
# Epoch 00050: val_accuracy did not improve from 0.56093
# Epoch 51/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6855 - accuracy: 0.5500 - mcc: 0.0882 - val_loss: 0.6875 - val_accuracy: 0.5367 - val_mcc: 0.0763
#
# Epoch 00051: val_accuracy did not improve from 0.56093
# Epoch 52/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6852 - accuracy: 0.5495 - mcc: 0.0845 - val_loss: 0.6893 - val_accuracy: 0.5412 - val_mcc: 0.0832
#
# Epoch 00052: val_accuracy did not improve from 0.56093
# Epoch 53/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6850 - accuracy: 0.5503 - mcc: 0.0854 - val_loss: 0.6903 - val_accuracy: 0.5287 - val_mcc: 0.0604
#
# Epoch 00053: val_accuracy did not improve from 0.56093
# Epoch 54/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6851 - accuracy: 0.5505 - mcc: 0.0859 - val_loss: 0.6914 - val_accuracy: 0.5430 - val_mcc: 0.1274
#
# Epoch 00054: val_accuracy did not improve from 0.56093
# Epoch 55/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6849 - accuracy: 0.5518 - mcc: 0.0902 - val_loss: 0.6927 - val_accuracy: 0.5421 - val_mcc: 0.1257
#
# Epoch 00055: val_accuracy did not improve from 0.56093
# Epoch 56/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6843 - accuracy: 0.5506 - mcc: 0.0902 - val_loss: 0.6916 - val_accuracy: 0.5457 - val_mcc: 0.1347
#
# Epoch 00056: val_accuracy did not improve from 0.56093
# Epoch 57/100
# 142/142 [==============================] - 158s 1s/step - loss: 0.6840 - accuracy: 0.5535 - mcc: 0.0945 - val_loss: 0.6912 - val_accuracy: 0.5520 - val_mcc: 0.1248
#
# Epoch 00057: val_accuracy did not improve from 0.56093
# Epoch 58/100
# 142/142 [==============================] - 157s 1s/step - loss: 0.6828 - accuracy: 0.5561 - mcc: 0.1001 - val_loss: 0.6908 - val_accuracy: 0.5278 - val_mcc: 0.0758
#
# Epoch 00058: val_accuracy did not improve from 0.56093
# Epoch 59/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6835 - accuracy: 0.5537 - mcc: 0.0943 - val_loss: 0.6912 - val_accuracy: 0.5412 - val_mcc: 0.1000
#
# Epoch 00059: val_accuracy did not improve from 0.56093
# Epoch 60/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6834 - accuracy: 0.5547 - mcc: 0.0962 - val_loss: 0.6882 - val_accuracy: 0.5412 - val_mcc: 0.1106
#
# Epoch 00060: val_accuracy did not improve from 0.56093
# Epoch 61/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6827 - accuracy: 0.5563 - mcc: 0.0999 - val_loss: 0.6933 - val_accuracy: 0.5287 - val_mcc: 0.0297
#
# Epoch 00061: val_accuracy did not improve from 0.56093
# Epoch 62/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6841 - accuracy: 0.5549 - mcc: 0.0975 - val_loss: 0.6876 - val_accuracy: 0.5493 - val_mcc: 0.1058
#
# Epoch 00062: val_accuracy did not improve from 0.56093
# Epoch 63/100
# 142/142 [==============================] - 154s 1s/step - loss: 0.6822 - accuracy: 0.5579 - mcc: 0.1063 - val_loss: 0.6884 - val_accuracy: 0.5421 - val_mcc: 0.1128
#
# Epoch 00063: val_accuracy did not improve from 0.56093
# Epoch 64/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6822 - accuracy: 0.5558 - mcc: 0.0981 - val_loss: 0.6927 - val_accuracy: 0.5215 - val_mcc: -0.0206
#
# Epoch 00064: val_accuracy did not improve from 0.56093
# Epoch 65/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6824 - accuracy: 0.5565 - mcc: 0.1017 - val_loss: 0.6886 - val_accuracy: 0.5457 - val_mcc: 0.0890
#
# Epoch 00065: val_accuracy did not improve from 0.56093
# Epoch 66/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6810 - accuracy: 0.5611 - mcc: 0.1079 - val_loss: 0.6907 - val_accuracy: 0.5314 - val_mcc: 0.0151
#
# Epoch 00066: val_accuracy did not improve from 0.56093
# Epoch 67/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6818 - accuracy: 0.5579 - mcc: 0.1055 - val_loss: 0.6872 - val_accuracy: 0.5565 - val_mcc: 0.0995
#
# Epoch 00067: val_accuracy did not improve from 0.56093
# Epoch 68/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6808 - accuracy: 0.5598 - mcc: 0.1099 - val_loss: 0.6878 - val_accuracy: 0.5484 - val_mcc: 0.0797
#
# Epoch 00068: val_accuracy did not improve from 0.56093
# Epoch 69/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6808 - accuracy: 0.5602 - mcc: 0.1086 - val_loss: 0.6852 - val_accuracy: 0.5493 - val_mcc: 0.1242
#
# Epoch 00069: val_accuracy did not improve from 0.56093
# Epoch 70/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6800 - accuracy: 0.5618 - mcc: 0.1131 - val_loss: 0.6901 - val_accuracy: 0.5367 - val_mcc: 0.1040
#
# Epoch 00070: val_accuracy did not improve from 0.56093
# Epoch 71/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6803 - accuracy: 0.5620 - mcc: 0.1113 - val_loss: 0.6887 - val_accuracy: 0.5412 - val_mcc: 0.1033
#
# Epoch 00071: val_accuracy did not improve from 0.56093
# Epoch 72/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6796 - accuracy: 0.5623 - mcc: 0.1125 - val_loss: 0.6884 - val_accuracy: 0.5358 - val_mcc: 0.0971
#
# Epoch 00072: val_accuracy did not improve from 0.56093
# Epoch 73/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6806 - accuracy: 0.5600 - mcc: 0.1082 - val_loss: 0.6918 - val_accuracy: 0.5349 - val_mcc: 0.0690
#
# Epoch 00073: val_accuracy did not improve from 0.56093
# Epoch 74/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6793 - accuracy: 0.5627 - mcc: 0.1140 - val_loss: 0.6850 - val_accuracy: 0.5547 - val_mcc: 0.1279
#
# Epoch 00074: val_accuracy did not improve from 0.56093
# Epoch 75/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6799 - accuracy: 0.5606 - mcc: 0.1095 - val_loss: 0.6861 - val_accuracy: 0.5421 - val_mcc: 0.0942
#
# Epoch 00075: val_accuracy did not improve from 0.56093
# Epoch 76/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6793 - accuracy: 0.5643 - mcc: 0.1177 - val_loss: 0.6984 - val_accuracy: 0.5296 - val_mcc: 0.0207
#
# Epoch 00076: val_accuracy did not improve from 0.56093
# Epoch 77/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6789 - accuracy: 0.5646 - mcc: 0.1183 - val_loss: 0.6890 - val_accuracy: 0.5466 - val_mcc: 0.0921
#
# Epoch 00077: val_accuracy did not improve from 0.56093
# Epoch 78/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6775 - accuracy: 0.5655 - mcc: 0.1212 - val_loss: 0.6837 - val_accuracy: 0.5717 - val_mcc: 0.1408
#
# Epoch 00078: val_accuracy improved from 0.56093 to 0.57168, saving model to /content/drive/MyDrive/programmers/project/model/DTML2.hdf5
# Epoch 79/100
# 142/142 [==============================] - 153s 1s/step - loss: 0.6765 - accuracy: 0.5674 - mcc: 0.1232 - val_loss: 0.6879 - val_accuracy: 0.5502 - val_mcc: 0.1066
#
# Epoch 00079: val_accuracy did not improve from 0.57168
# Epoch 80/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6769 - accuracy: 0.5678 - mcc: 0.1270 - val_loss: 0.6908 - val_accuracy: 0.5358 - val_mcc: 0.1020
#
# Epoch 00080: val_accuracy did not improve from 0.57168
# Epoch 81/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6774 - accuracy: 0.5665 - mcc: 0.1221 - val_loss: 0.6875 - val_accuracy: 0.5385 - val_mcc: 0.0554
#
# Epoch 00081: val_accuracy did not improve from 0.57168
# Epoch 82/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6767 - accuracy: 0.5664 - mcc: 0.1254 - val_loss: 0.6910 - val_accuracy: 0.5341 - val_mcc: 0.0678
#
# Epoch 00082: val_accuracy did not improve from 0.57168
# Epoch 83/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6763 - accuracy: 0.5674 - mcc: 0.1260 - val_loss: 0.6846 - val_accuracy: 0.5502 - val_mcc: 0.1131
#
# Epoch 00083: val_accuracy did not improve from 0.57168
# Epoch 84/100
# 142/142 [==============================] - 149s 1s/step - loss: 0.6757 - accuracy: 0.5691 - mcc: 0.1273 - val_loss: 0.6820 - val_accuracy: 0.5636 - val_mcc: 0.1223
#
# Epoch 00084: val_accuracy did not improve from 0.57168
# Epoch 85/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6752 - accuracy: 0.5700 - mcc: 0.1304 - val_loss: 0.6863 - val_accuracy: 0.5511 - val_mcc: 0.0984
#
# Epoch 00085: val_accuracy did not improve from 0.57168
# Epoch 86/100
# 142/142 [==============================] - 149s 1s/step - loss: 0.6748 - accuracy: 0.5708 - mcc: 0.1317 - val_loss: 0.6951 - val_accuracy: 0.5206 - val_mcc: 0.0470
#
# Epoch 00086: val_accuracy did not improve from 0.57168
# Epoch 87/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6737 - accuracy: 0.5713 - mcc: 0.1301 - val_loss: 0.6895 - val_accuracy: 0.5349 - val_mcc: 0.0871
#
# Epoch 00087: val_accuracy did not improve from 0.57168
# Epoch 88/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6748 - accuracy: 0.5716 - mcc: 0.1322 - val_loss: 0.6924 - val_accuracy: 0.5251 - val_mcc: 0.0313
#
# Epoch 00088: val_accuracy did not improve from 0.57168
# Epoch 89/100
# 142/142 [==============================] - 151s 1s/step - loss: 0.6755 - accuracy: 0.5709 - mcc: 0.1308 - val_loss: 0.6940 - val_accuracy: 0.5242 - val_mcc: 0.0425
#
# Epoch 00089: val_accuracy did not improve from 0.57168
# Epoch 90/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6741 - accuracy: 0.5706 - mcc: 0.1302 - val_loss: 0.6936 - val_accuracy: 0.5314 - val_mcc: 0.0699
#
# Epoch 00090: val_accuracy did not improve from 0.57168
# Epoch 91/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6739 - accuracy: 0.5702 - mcc: 0.1292 - val_loss: 0.6938 - val_accuracy: 0.5314 - val_mcc: 0.0623
#
# Epoch 00091: val_accuracy did not improve from 0.57168
# Epoch 92/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6722 - accuracy: 0.5769 - mcc: 0.1425 - val_loss: 0.6939 - val_accuracy: 0.5260 - val_mcc: 0.0527
#
# Epoch 00092: val_accuracy did not improve from 0.57168
# Epoch 93/100
# 142/142 [==============================] - 149s 1s/step - loss: 0.6719 - accuracy: 0.5752 - mcc: 0.1396 - val_loss: 0.6933 - val_accuracy: 0.5412 - val_mcc: 0.0936
#
# Epoch 00093: val_accuracy did not improve from 0.57168
# Epoch 94/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6715 - accuracy: 0.5744 - mcc: 0.1394 - val_loss: 0.6931 - val_accuracy: 0.5278 - val_mcc: 0.1028
#
# Epoch 00094: val_accuracy did not improve from 0.57168
# Epoch 95/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6720 - accuracy: 0.5760 - mcc: 0.1435 - val_loss: 0.6947 - val_accuracy: 0.5296 - val_mcc: 0.1017
#
# Epoch 00095: val_accuracy did not improve from 0.57168
# Epoch 96/100
# 142/142 [==============================] - 152s 1s/step - loss: 0.6717 - accuracy: 0.5755 - mcc: 0.1407 - val_loss: 0.6916 - val_accuracy: 0.5305 - val_mcc: 0.0637
#
# Epoch 00096: val_accuracy did not improve from 0.57168
# Epoch 97/100
# 142/142 [==============================] - 149s 1s/step - loss: 0.6709 - accuracy: 0.5770 - mcc: 0.1434 - val_loss: 0.6874 - val_accuracy: 0.5484 - val_mcc: 0.1343
#
# Epoch 00097: val_accuracy did not improve from 0.57168
# Epoch 98/100
# 142/142 [==============================] - 149s 1s/step - loss: 0.6707 - accuracy: 0.5783 - mcc: 0.1487 - val_loss: 0.6902 - val_accuracy: 0.5269 - val_mcc: 0.0588
#
# Epoch 00098: val_accuracy did not improve from 0.57168
# Epoch 99/100
# 142/142 [==============================] - 150s 1s/step - loss: 0.6711 - accuracy: 0.5771 - mcc: 0.1459 - val_loss: 0.6946 - val_accuracy: 0.5152 - val_mcc: 0.0397
#
# Epoch 00099: val_accuracy did not improve from 0.57168
# Epoch 100/100
# 142/142 [==============================] - 148s 1s/step - loss: 0.6705 - accuracy: 0.5783 - mcc: 0.1460 - val_loss: 0.6912 - val_accuracy: 0.5394 - val_mcc: 0.0815
#
# Epoch 00100: val_accuracy did not improve from 0.57168

# %%
train_pred = model.predict((X_train_s, X_train_m))
val_pred = model.predict((X_valid_s, X_valid_m))
test_pred = model.predict((X_test_s, X_test_m))

# #Print evaluation metrics for all datasets
train_eval = model.evaluate((X_train_s, X_train_m), y_train_m, verbose=0)
val_eval = model.evaluate((X_valid_s, X_valid_m), y_valid_m, verbose=0)
test_eval = model.evaluate((X_test_s, X_test_m), y_test_m, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, ACC: {:.4f}, MCC: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))
# Out:
#
# Evaluation metrics
# Training Data - Loss: 0.6723, ACC: 0.5589, MCC: 0.1606
# Validation Data - Loss: 0.7215, ACC: 0.4373, MCC: 0.0838
# Test Data - Loss: 0.7001, ACC: 0.5556, MCC: -0.0044

# %% [markdown]
# ## Back Testing

# %%
import matplotlib.pyplot as plt
import datetime as dt
stock_raw_data = pd.read_csv('kospi31-2003-2021.csv')
seed = 10000000 
threshold_prob = 0.6
result1 = dict.fromkeys(list(stock_raw_data['name']))
del result1['kospi50_index'] 
for idx, key in enumerate(result1.keys()):
  result1[key] = idx 
idx_to_name = {}
for k, v in result1.items():
  idx_to_name[v] = k 
first_seed = seed
my_seed = [first_seed]
buy_date_for_x = [dt.datetime.strptime(str(stock_test_data_date['삼성전자'][0]) , "%Y%m%d") - dt.timedelta(days=1)]
for test_day_idx, day_predict in enumerate(test_pred):
  max_idx = -1 
  max_prob = 0
  for stock_idx, predict in enumerate(list(day_predict)):
    if predict[0] > max_prob:
      max_idx = stock_idx 
      max_prob = predict[0] 
    
  # 확률이 50% 이상이면(추후에 더 높게 조정 가능)
  if max_prob > threshold_prob:
    buy_stock_name = idx_to_name[max_idx]
    buy_stock_day  = stock_test_data_date[buy_stock_name][test_day_idx] 
    
    open = float(stock_raw_data[(stock_raw_data['name'] == buy_stock_name) & (stock_raw_data['date'] == buy_stock_day)]['open'])
    close = float(stock_raw_data[(stock_raw_data['name'] == buy_stock_name) & (stock_raw_data['date'] == buy_stock_day)]['close'])
    
    
    buy_stock_num = seed // open 
    profit_per_stock = close - open
    net = round(buy_stock_num * (profit_per_stock) - close*buy_stock_num*0.0023 , 2) 
    
    seed += net 
    seed = round(seed, 2)
    my_seed.append(seed)
    buy_date_for_x.append(dt.datetime.strptime(str(buy_stock_day) , "%Y%m%d")) 
    

print("첫 금액: {}\    {}일치 매수 후 금액: {}\  수익률: {} %  거래 횟수: {}   ----  확률 threshold : {} ".format(first_seed, len(test_pred), seed, round(((seed - first_seed)/seed)*100 , 2), len(my_seed)-1, threshold_prob )) 

fig = plt.figure(figsize = (16,3))
plt.title('My Account') 
plt.ylim(min(my_seed) - 100000, max(my_seed) + 100000)
plt.plot(buy_date_for_x, my_seed, color = 'red') 
plt.show()
# Out:
# 첫 금액: 10000000\    36일치 매수 후 금액: 9427375.63\  수익률: -6.07 %  거래 횟수: 7----  확률 threshold : 0.6
